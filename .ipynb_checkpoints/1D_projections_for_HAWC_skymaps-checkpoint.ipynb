# %% [markdown]
# # 1D projections for HAWC and IceCube

# %% [markdown]
# #### Import Statements

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import healpy as hp
import os
import astropy
import scipy
from scipy.optimize import curve_fit
import math
import glob as gb
import sys
sys.path.append('/data/user/fawolf')
from smooth import smooth, smooth_significance

# %% [markdown]
# #### HAWC Files from the server

# %%
#HAWC bins
bin_names = sorted(os.listdir('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco'))
print(bin_names)
# Out:
# ['bin0', 'bin1', 'bin2', 'bin3']

# %% [markdown]
# #### IceCube files from the server

# %%
#IceCube data files
directory_path = '/data/ana/CosmicRay/Anisotropy/IceCube/twelve_year/maps/merged'
pattern = 'IC86_24H_sid_*.fits'
IceCube_file_path = gb.glob(directory_path + "/" + pattern)
IceCube_file_path = sorted(IceCube_file_path)

for file_path in IceCube_file_path:
    print(file_path)
# Out:
# /data/ana/CosmicRay/Anisotropy/IceCube/twelve_year/maps/merged/IC86_24H_sid_4-4.25GeV.fits
# /data/ana/CosmicRay/Anisotropy/IceCube/twelve_year/maps/merged/IC86_24H_sid_4.25-4.5GeV.fits
# /data/ana/CosmicRay/Anisotropy/IceCube/twelve_year/maps/merged/IC86_24H_sid_4.5-4.75GeV.fits
# /data/ana/CosmicRay/Anisotropy/IceCube/twelve_year/maps/merged/IC86_24H_sid_4.75-5GeV.fits
# /data/ana/CosmicRay/Anisotropy/IceCube/twelve_year/maps/merged/IC86_24H_sid_5-5.25GeV.fits
# /data/ana/CosmicRay/Anisotropy/IceCube/twelve_year/maps/merged/IC86_24H_sid_5.25-5.5GeV.fits
# /data/ana/CosmicRay/Anisotropy/IceCube/twelve_year/maps/merged/IC86_24H_sid_5.5-6GeV.fits
# /data/ana/CosmicRay/Anisotropy/IceCube/twelve_year/maps/merged/IC86_24H_sid_6-6.5GeV.fits
# /data/ana/CosmicRay/Anisotropy/IceCube/twelve_year/maps/merged/IC86_24H_sid_6.5-100GeV.fits

# %% [markdown]
# #### Curve fit function

# %%
#this is the function for the dipole + quadropole + octopole
def func(x, A1, phi1, A2, phi2, A3, phi3):
    return (A1 * np.cos(x + phi1)) + (A2 * np.cos(2*x + phi2)) + (A3 * np.cos(3*x + phi3))

# %% [markdown]
# #### Error band for curve fit

# %%
def fit_err_band(x, ri_fit, ri_cov, func):
    ymax = -np.ones(len(x))*np.inf
    ymin = np.ones(len(x))*np.inf
    errs = np.sqrt(np.diag(ri_cov))
    for i in range(-1,2):
        for j in range(-1,2):
            for k in range(-1,2):
                for l in range(-1,2):
                    for m in range(-1,2):
                        for n in range(-1,2):
                            pvals = np.array(ri_fit) + np.array(errs)*np.array([i,j,k,l,m,n]) 
                            ymin = np.minimum(ymin, func(x,*pvals)) 
                            ymax = np.maximum(ymax, func(x,*pvals)) 
                            
    return ymin, ymax

# %% [markdown]
# #### Correction function

# %%
polynomial_coeff =  [-4.69087062e-04, -2.25275535e-03, -4.40691390e-03, -4.53214075e-03, -2.17028919e-03, -6.84256681e-05]
cosine_fit =  [ 0.00036938, -0.02608274]

polynomial = np.poly1d(polynomial_coeff)

def cosine_function(x,A,phi):
    return A*np.cos(x+phi)

def correction(dec):
    expected = cosine_function(np.radians(dec),*cosine_fit)
    observed = polynomial(np.radians(dec))
    return expected/observed

# %% [markdown]
# #### Function to plot the relative intensity with curve fit for IceCube

# %%
def plot_id_w_errors_icecube(data, background, relative_intensity, title='Relative Intensity',top=-21, bottom=-24,bins=24, alpha = 20, show_plot = True):
    
    #IceCube#
    npix = len(data)
    nside = hp.npix2nside(npix)
    #nside = int(math.sqrt(npix/12))p
    
    min_pix = hp.ang2pix(nside, 0, top, lonlat=True) #defines ranges
    max_pix = hp.ang2pix(nside, 0, bottom, lonlat=True)
    umpix = range(min_pix, max_pix)

    #healpy UNSEEN to mask the values not needed
    relative_intensity[:min_pix] = hp.UNSEEN
    relative_intensity[max_pix:] = hp.UNSEEN
    
    az_bins = np.linspace(np.pi/24, 2*np.pi, bins) #right ascension
    bin_vals = np.zeros(bins) #relative intensy
    bin_counts = np.zeros(bins)
    bin_data = np.zeros(bins) #data
    bin_bg = np.zeros(bins) #background
    zen, az = hp.pix2ang(nside,range(npix))

    for pix in umpix:

        ibin = np.digitize(az[pix], az_bins)
        bin_vals[ibin]+=relative_intensity[pix] * correction(dec[pix])  #relative intensity
        bin_counts[ibin]+= 1 #1
        bin_data[ibin] += data[pix] #data
        bin_bg[ibin] += background[pix] #background

    yerr2_icecube = np.power(bin_data/bin_bg,2)*(1/bin_data+1/bin_bg/alpha)
    #bin_vals = np.nan_to_num(bin_vals/bin_counts-1)

    if show_plot:

        ri_fit, ri_cov = curve_fit(func, az_bins, bin_vals/bin_counts)
        #IceCube#
    
        #Plotting the data#
        # *ri_fit is the unpacked list of the ri_fit array   
        plt.errorbar(np.degrees(az_bins),bin_vals/bin_counts*1e4,yerr=np.sqrt(yerr2_icecube)*1e4,fmt='.')
        plt.errorbar(np.degrees(az_bins) , func(az_bins, *ri_fit)*1e4, label = 'IceCube', color = 'blue')
        y_min, y_max = fit_err_band(np.linspace(0,2*np.pi, 100), ri_fit,ri_cov, func)
        plt.fill_between(np.degrees(np.linspace(0,2*np.pi, 100)), y_min*1e4, y_max*1e4, alpha = 0.3, color = 'blue') #alpha is the transparancy
        plt.title("1-D projection of adjacent declination bins")
        plt.xlabel("RA (°)")
        plt.ylabel("Relative Intensity[10^-3]")
        # plt.legend(loc = 'lower left')

    return yerr2_icecube, bin_vals

# %% [markdown]
# #### Y error calculation for IceCube

# %%
def calculate_y_errors_icecube(data, background, relative_intensity, title = 'Y error calculation for IceCube', top = -21, bottom = -24, bins = 24, alpha = 20):
    #IceCube#
    npix = len(data)
    nside = hp.npix2nside(npix)

    #pix2ang(nside, ipix[, nest, lonlat]) , lonlot = TURE is right ascension and declanation
    #healpy.query_disc() - will give you a list of pixels in the radius 
    
    min_pix = hp.ang2pix(nside, 0, top, lonlat=True) #defines ranges
    max_pix = hp.ang2pix(nside, 0, bottom, lonlat=True)
    umpix = range(min_pix, max_pix)

    #set the values not needed to 0
    # relative_intensity[:min_pix] = hp.UNSEEN
    # relative_intensity[max_pix:] = hp.UNSEEN
    relative_intensity = relative_intensity[min_pix:max_pix]
    data = data[min_pix:max_pix]
    background = background[min_pix:max_pix]
    
    az_bins = np.linspace(np.pi/24, 2*np.pi, bins) #right ascension
    bin_vals = np.zeros(bins) #relative intensity
    bin_counts = np.zeros(bins) #background
    bin_data = np.zeros(bins) #data
    bin_bg = np.zeros(bins)
    # zen, az = hp.pix2ang(nside,range(npix))
    zen, az = hp.pix2ang(nside, range(min_pix, max_pix))
    # ra, dec = hp.pix2ang(nside,range(npix), lonlat = True)
    ra, dec = hp.pix2ang(nside,range(min_pix, max_pix), lonlat = True)

    # for pix in umpix:

    #     ibin = np.digitize(az[pix], az_bins)
    #     bin_vals[ibin]+=relative_intensity[pix] * correction(dec[pix])  #relative intensity
    #     bin_counts[ibin]+= 1 #1
    #     bin_data[ibin] += data[pix] #data
    #     bin_bg[ibin] += background[pix] #background
    for i, pix in enumerate(range(min_pix, max_pix)):
        ibin = np.digitize(az[i], az_bins)
        bin_vals[ibin] += relative_intensity[i]  # relative intensity
        bin_counts[ibin] += 1  # 1
        bin_data[ibin] += data[i]  # data
        bin_bg[ibin] += background[i]  # background

    yerr2_icecube = np.power(bin_data/bin_bg,2)*(1/bin_data+1/bin_bg/alpha)
    return yerr2_icecube, bin_vals

# %% [markdown]
# #### Function to plot the relative intensity with Mollview for IceCube

# %%
def smooth_iceCube(relative_intensity, radius = 5, cutoff = True): #Filepath, radius of tophat smoothing
    #Change degree to radians
    radius = math.radians(radius)
    #Loop over all filepaths in list
    #Select current relative_intensity array
    # relative_intensity = hp.read_map(relative_intensity_filepath)

    #Return original map if radius = 0
    if radius == 0:
        if cutoff == True:
            hp.mollview(relative_intensity, min = -1e-3, max = 1e-3)          
        elif cutoff == False:
            hp.mollview(relative_intensity)
        return relative_intensity

    #Calculate Nside (num_pix = 12*Nside**2) Note: should be 64
    num_pix = len(relative_intensity)
    nside = hp.npix2nside(num_pix)

    #Calculate indices for Lat 70 and Lat 20
    top_val = hp.pixelfunc.ang2pix(nside, 0, -30, lonlat = True)
    bottom_val = hp.pixelfunc.ang2pix(nside, 0, -90, lonlat = True)
    

    smooth_map = np.zeros(num_pix)
    
    #Smooth all pixels by taking the average of its neighbors
    for pixel in range(len(relative_intensity)):       
    #     #Set pixel to 0 if it's outside of the bounds
    #     if pixel > bottom_val or pixel < top_val:
    #         relative_intensity[pixel] = 0
    #         continue
            
        #Get list of all pixels surrounding each pixel with radius R
        theta, phi = hp.pixelfunc.pix2ang(nside, pixel)
        vec = hp.pixelfunc.ang2vec(theta, phi)
        list_pix = hp.query_disc(nside, vec, radius)   
        #Set original pixel to that average value
        # relative_intensity[pixel] = relative_intensity[list_pix].mean()
        smooth_map[pixel] = relative_intensity[list_pix].mean()

    
    # #Remove all values outside of the indices
    for j in range(len(relative_intensity)):
        if j < bottom_val or j > top_val:
            smooth_map[j] = hp.UNSEEN

    
    #Call mollview to show graph Note: Cutoff manually sets the bounds for the values to be between +- 1e-3
    if cutoff == True:
        hp.mollview(smooth_map, min = -1e-3, max = 1e-3)          
    elif cutoff == False:
        hp.mollview(smooth_map)
    return smooth_map

# %% [markdown]
# #### Plotting IceCube graphs

# %%
#call this function in the plot_1d_w_errors function
#plot the icecube graph
relative_intensity = []

for file_path in IceCube_file_path:
    
    data_column = hp.read_map(file_path, field = 0)
    
    background_column = hp.read_map(file_path, field = 1)

    # relative_intensity = (np.nan_to_num(data_column / background_column) - 1)

    #a few values in the data and background were 0, so they couldnt be divided
    #replacing the zero values with nan to get relative intensity
    # data_column = np.where((data_column == 0) | np.isnan(data_column), np.nan, data_column)
    # background_column = np.where((background_column == 0) | np.isnan(background_column), np.nan, background_column)

    #to see how many number of nan values are there in the arrays
    # nan_count_data = np.sum(np.isnan(data_column))
    # nan_count_background = np.sum(np.isnan(background_column))

    # if nan_count_data == nan_count_background:
        
        #excluding the number of nan values to get only finite values
        # data_mask = np.isfinite(data_column)
        # background_mask = np.isfinite(background_column)
        # data_column = data_column[data_mask]
        # background_column = background_column[background_mask]
    
        #the IC86_24H_sid_6.5-100GeV.fits had different number of nan values for data and background, so I will be excluding that file
    relative_intensity = (np.nan_to_num(data_column / background_column) - 1)

    print(os.path.basename(file_path))
    plot_id_w_errors_icecube(data_column, background_column, relative_intensity)
    # smooth_iceCube(relative_intensity, cutoff = False)
    plt.show()
    print()
# Out:
# IC86_24H_sid_4-4.25GeV.fits
# /tmp/ipykernel_499/1143910599.py:31: RuntimeWarning: invalid value encountered in divide
#   relative_intensity = (np.nan_to_num(data_column / background_column) - 1)
# IC86_24H_sid_4.25-4.5GeV.fits
# IC86_24H_sid_4.5-4.75GeV.fits
# IC86_24H_sid_4.75-5GeV.fits
# IC86_24H_sid_5-5.25GeV.fits
# IC86_24H_sid_5.25-5.5GeV.fits
# IC86_24H_sid_5.5-6GeV.fits
# IC86_24H_sid_6-6.5GeV.fits
# IC86_24H_sid_6.5-100GeV.fits

# %% [markdown]
# #### Smooth function for relative intensity HAWC

# %%
def smooth(relative_intensity_filepath, radius = 10, cutoff = True): #Filepath, radius of tophat smoothing
    #Change degree to radians
    radius = math.radians(radius)
    #Loop over all filepaths in list
    #Select current relative_intensity array
    relative_intensity = hp.read_map(relative_intensity_filepath)

    #Return original map if radius = 0
    if radius == 0:
        if cutoff == True:
            hp.mollview(relative_intensity, min = -1e-3, max = 1e-3)          
        elif cutoff == False:
            hp.mollview(relative_intensity)
        return relative_intensity

    #Calculate Nside (num_pix = 12*Nside**2) Note: should be 64
    num_pix = len(relative_intensity)
    Nside = int(math.sqrt(num_pix/12))

    #Calculate indices for Lat 70 and Lat 20
    top_val = hp.pixelfunc.ang2pix(Nside, 0, 70, lonlat = True)
    bottom_val = hp.pixelfunc.ang2pix(Nside, 0, -20, lonlat = True)
    

    #Smooth all pixels by taking the average of its neighbors
    for pixel in range(len(relative_intensity)):       
        #Set pixel to 0 if it's outside of the bounds
        if pixel > bottom_val or pixel < top_val:
            relative_intensity[pixel] = 0
            continue
            
        #Get list of all pixels surrounding each pixel with radius R
        theta, phi = hp.pixelfunc.pix2ang(Nside, pixel)
        vec = hp.pixelfunc.ang2vec(theta, phi)
        list_pix = hp.query_disc(Nside, vec, radius)   
        #Set original pixel to that average value
        relative_intensity[pixel] = relative_intensity[list_pix].mean()


    # #Remove all values outside of the indices
    for j in range(len(relative_intensity)):
        if j > bottom_val or j < top_val:
            relative_intensity[j] = hp.UNSEEN

    
    #Call mollview to show graph Note: Cutoff manually sets the bounds for the values to be between +- 1e-3
    if cutoff == True:
        hp.mollview(relative_intensity, min = -1e-3, max = 1e-3)          
    elif cutoff == False:
        hp.mollview(relative_intensity)
    return relative_intensity

# %% [markdown]
# #### Function to plot the relative intensity with curve fit for IceCube

# %%
def plot_1d_w_errrors(data,background,relative_intensity,title='Relative Intensity',top=70, bottom=-20,bins=24, alpha = 1, show_plot = True):
    
    #HAWC#
    npix = len(data)
    nside = hp.npix2nside(npix)  #how to divide the sky , nside 64

    #pix2ang(nside, ipix[, nest, lonlat]) , lonlot = TURE is right ascension and declanation
    #healpy.query_disc() - will give you a list of pixels in the radius 
    
    min_pix = hp.ang2pix(nside, 0, top, lonlat=True) #defines ranges
    max_pix = hp.ang2pix(nside, 0, bottom, lonlat=True)
    umpix = range(min_pix, max_pix)  #unmasked pixs

    #healpy UNSEEN to mask the values not needed
    relative_intensity[:min_pix] = hp.UNSEEN
    relative_intensity[max_pix:] = hp.UNSEEN
    
    az_bins = np.linspace(np.pi/24, 2*np.pi, bins) #right ascension
    bin_vals = np.zeros(bins) #relative intensity
    bin_counts = np.zeros(bins) #background
    bin_data = np.zeros(bins) #data
    bin_bg = np.zeros(bins)
    zen, az = hp.pix2ang(nside,range(npix))

    for pix in umpix:

        ibin = np.digitize(az[pix], az_bins)
        bin_vals[ibin]+=relative_intensity[pix] #relative intensity
        bin_counts[ibin]+= 1 #1
        bin_data[ibin] += data[pix] #data
        bin_bg[ibin] += background[pix] #background

    yerr2_hawc = np.power(bin_data/bin_bg,2)*(1/bin_data+1/bin_bg/alpha)
    #bin_vals = np.nan_to_num(bin_vals/bin_counts-1)

    if show_plot:

        ri_fit, ri_cov = curve_fit(func, az_bins, bin_vals/bin_counts)
        #HAWC#
    
        #Plotting the data#
        # *ri_fit is the unpacked list of the ri_fit array   
        plt.errorbar(np.degrees(az_bins),bin_vals/bin_counts*1e4,yerr=np.sqrt(yerr2_hawc)*1e4,fmt='.', color = 'orange')
        plt.errorbar(np.degrees(az_bins) , func(az_bins, *ri_fit)*1e4, label = 'HAWC', color = 'orange')
        y_min, y_max = fit_err_band(np.linspace(0,2*np.pi, 100), ri_fit,ri_cov, func)
        plt.fill_between(np.degrees(np.linspace(0,2*np.pi, 100)), y_min*1e4, y_max*1e4, alpha = 0.3, color = 'orange') #alpha is the transparancy
        plt.title("1-D projection of adjacent declination bins")
        plt.xlabel("RA (°)")
        plt.ylabel("Relative Intensity[10^-3]")
        # plt.legend(loc = 'lower left')
        # hp.mollview(relative_intensity)
        #Plotting the data#

    return yerr2_hawc, bin_vals

# %% [markdown]
# #### Y error calculation for HAWC

# %%
def calculate_y_errors_hawc(data, background, relative_intensity, title = 'Y error calculation', top = 70, bottom = -20, bins = 24, alpha = 1):
    #HAWC#
    npix = len(data)
    nside = hp.npix2nside(npix)  #how to divide the sky , nside 64

    #pix2ang(nside, ipix[, nest, lonlat]) , lonlot = TURE is right ascension and declanation
    #healpy.query_disc() - will give you a list of pixels in the radius 
    
    min_pix = hp.ang2pix(nside, 0, top, lonlat=True) #defines ranges
    max_pix = hp.ang2pix(nside, 0, bottom, lonlat=True)
    umpix = range(min_pix, max_pix)  #unmasked pixs

    #set the values not required to 0
    # relative_intensity[:min_pix] = hp.UNSEEN
    # relative_intensity[max_pix:] = hp.UNSEEN
    relative_intensity = relative_intensity[min_pix:max_pix]
    data = data[min_pix:max_pix]
    background = background[min_pix:max_pix]
    
    az_bins = np.linspace(np.pi/24, 2*np.pi, bins) #right ascension
    bin_vals = np.zeros(bins) #relative intensity
    bin_counts = np.zeros(bins) #background
    bin_data = np.zeros(bins) #data
    bin_bg = np.zeros(bins)
    # zen, az = hp.pix2ang(nside,range(npix))
    zen, az = hp.pix2ang(nside, range(min_pix, max_pix))

    # for pix in umpix:

    #     ibin = np.digitize(az[pix], az_bins)
    #     bin_vals[ibin]+=relative_intensity[pix] #relative intensity
    #     bin_counts[ibin]+= 1 #1
    #     bin_data[ibin] += data[pix] #data
    #     bin_bg[ibin] += background[pix] #background

    for i, pix in enumerate(range(min_pix, max_pix)):
        ibin = np.digitize(az[i], az_bins)
        bin_vals[ibin] += relative_intensity[i]  # relative intensity
        bin_counts[ibin] += 1  # 1
        bin_data[ibin] += data[i]  # data
        bin_bg[ibin] += background[i]  # background

    yerr2_hawc = np.power(bin_data/bin_bg,2)*(1/bin_data+1/bin_bg/alpha)
    return yerr2_hawc, bin_vals

# %% [markdown]
# #### Plotting HAWC graphs

# %%
#plot the healpy graph in this for loop only

data_final = []
relative_int_final = []
background_final = []

for bin_name in bin_names:
    data_path = '/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/{0}/data_HAWC_64_360.fits'.format(bin_name)
    data = hp.read_map(data_path)
    data_final.append(data)
    
    relative_intensity_path = '/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/{0}/CR_HAWC_64_360_iteration20.fits'.format(bin_name)
    relative_intensity = hp.read_map(relative_intensity_path)
    relative_int_final.append(relative_intensity)
    
    #relative_intensity = (data/background) - 1
    background = data / (relative_intensity + 1)
    background_final.append(background)
    
    print(bin_name)
    plot_1d_w_errrors(data,background,relative_intensity)
    smooth(relative_intensity_path, radius = 10, cutoff = True)
    plt.show()
# Out:
# bin0
# bin1
# bin2
# bin3

# %% [markdown]
# #### Chi_squared test function

# %%
# Using the chi^2 distribution to check if the graphs are compatible or not
def chi_squared(relative_int_1, relative_int_2, yerr1, yerr2):
    
    delta = relative_int_1 - relative_int_2  # Calculate the difference between the two datasets' y-values
    chi_sq_values = np.power(delta, 2) / (yerr1 + yerr2) # Calculate the squared differences divided by the sum of the squared errors
    chi_sq_total = np.sum(chi_sq_values)  # Sum up all the chi-squared values to get the chi-squared statistic

    # Calculate the reduced chi-squared statistic by dividing by the degrees of freedom
    degrees_of_freedom = len(relative_int_1) - 1  # This is 23 if you have 24 bins
    chi_squared_reduced = chi_sq_total / degrees_of_freedom
    
    return chi_squared_reduced

# %% [markdown]
# #### IceCube files to be used for combined graph

# %%
IceCube_usage_file_path = []
IceCube_usage_file_path.append(IceCube_file_path[0])
IceCube_usage_file_path.append(IceCube_file_path[2])
IceCube_usage_file_path.append(IceCube_file_path[3])
print(IceCube_usage_file_path[1])
# Out:
# /data/ana/CosmicRay/Anisotropy/IceCube/twelve_year/maps/merged/IC86_24H_sid_4.5-4.75GeV.fits

# %% [markdown]
# #### Combined Graph - 1

# %%
#Combining the 1st bin of IceCube with bin1 of HAWC
data1_iceCube = hp.read_map(IceCube_usage_file_path[0], field = 0)
background1_iceCube = hp.read_map(IceCube_usage_file_path[0], field = 1)
rel_int1_iceCube = (np.nan_to_num(data1_iceCube / background1_iceCube) - 1)
# rel_int1_iceCube = np.flip(rel_int1_iceCube)
plot_id_w_errors_icecube(data1_iceCube, background1_iceCube, rel_int1_iceCube, top = -21, bottom = -24, alpha = 20)

data1_hawc = hp.read_map('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/bin1/data_HAWC_64_360.fits')
rel_int1_hawc = hp.read_map('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/bin1/CR_HAWC_64_360_iteration20.fits')
# rel_int1_hawc= np.flip(rel_int1_hawc)
background1_hawc = data1_hawc / (rel_int1_hawc + 1)
plot_1d_w_errrors(data1_hawc,background1_hawc,rel_int1_hawc, top = -21, bottom = -24, alpha = 1)
plt.gca().invert_xaxis()
plt.legend(loc = 'lower left')
plt.show()
# Out:
# /tmp/ipykernel_499/3021888182.py:4: RuntimeWarning: invalid value encountered in divide
#   rel_int1_iceCube = (np.nan_to_num(data1_iceCube / background1_iceCube) - 1)

# %%
data1_iceCube = hp.read_map(IceCube_usage_file_path[0], field = 0)
background1_iceCube = hp.read_map(IceCube_usage_file_path[0], field = 1)
rel_int1_iceCube = (np.nan_to_num(data1_iceCube / background1_iceCube) - 1)

data1_hawc = hp.read_map('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/bin1/data_HAWC_64_360.fits')
rel_int1_hawc = hp.read_map('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/bin1/CR_HAWC_64_360_iteration20.fits')
background1_hawc = data1_hawc / (rel_int1_hawc + 1)

#chi_squared test for Combined Graph - 1
yerr_hawc_1 , bin_vals_hawc_1 = calculate_y_errors_hawc(data1_hawc, background1_hawc, rel_int1_hawc, top = -21, bottom = -23, alpha = 1)
yerr_icecube_1 , bin_vals_icecube_1 = calculate_y_errors_icecube(data1_iceCube, background1_iceCube,rel_int1_iceCube, top = -21, bottom = -23, alpha = 20)
chi_squared_test_result_1 = chi_squared(bin_vals_icecube_1 , bin_vals_hawc_1 , yerr_icecube_1 , yerr_hawc_1 )
print(chi_squared_test_result_1)
# Out:
# 803.6075482094978
# /tmp/ipykernel_329/1134038674.py:3: RuntimeWarning: invalid value encountered in divide
#   rel_int1_iceCube = (np.nan_to_num(data1_iceCube / background1_iceCube) - 1)

# %% [markdown]
# #### Combined Graph - 2

# %%
#Combining the 3rd bin of IceCube with bin2 of HAWC
data2_iceCube = hp.read_map(IceCube_usage_file_path[1], field = 0)
background2_iceCube = hp.read_map(IceCube_usage_file_path[1], field = 1)
rel_int2_iceCube = (np.nan_to_num(data2_iceCube / background2_iceCube) - 1)
plot_id_w_errors_icecube(data2_iceCube, background2_iceCube, rel_int2_iceCube, top = -18, bottom = -29)

data2_hawc = hp.read_map('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/bin2/data_HAWC_64_360.fits')
rel_int2_hawc = hp.read_map('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/bin2/CR_HAWC_64_360_iteration20.fits')
background2_hawc = data2_hawc / (rel_int2_hawc + 1)
plot_1d_w_errrors(data2_hawc,background2_hawc,rel_int2_hawc, top = -18, bottom = -29)
plt.gca().invert_xaxis()
plt.legend(loc = 'lower left')
plt.show()
# Out:
# /tmp/ipykernel_329/741745566.py:4: RuntimeWarning: invalid value encountered in divide
#   rel_int2_iceCube = (np.nan_to_num(data2_iceCube / background2_iceCube) - 1)

# %%
data2_iceCube = hp.read_map(IceCube_usage_file_path[1], field = 0)
background2_iceCube = hp.read_map(IceCube_usage_file_path[1], field = 1)
rel_int2_iceCube = (np.nan_to_num(data2_iceCube / background2_iceCube) - 1)

data2_hawc = hp.read_map('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/bin2/data_HAWC_64_360.fits')
rel_int2_hawc = hp.read_map('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/bin2/CR_HAWC_64_360_iteration20.fits')
background2_hawc = data2_hawc / (rel_int2_hawc + 1)

#chi_squared test for Combined Graph - 2
yerr_hawc_2 , bin_vals_hawc_2 = calculate_y_errors_hawc(data2_hawc, background2_hawc, rel_int2_hawc, top = -18, bottom = -29, alpha = 1)
yerr_icecube_2 , bin_vals_icecube_2 = calculate_y_errors_icecube(data2_iceCube, background2_iceCube,rel_int2_iceCube, top = -18, bottom = -29, alpha = 20)
chi_squared_test_result_2 = chi_squared(bin_vals_icecube_2 , bin_vals_hawc_2 , yerr_icecube_2 , yerr_hawc_2 )
print(chi_squared_test_result_2)
# Out:
# 50593.29076315155
# /tmp/ipykernel_329/656272584.py:3: RuntimeWarning: invalid value encountered in divide
#   rel_int2_iceCube = (np.nan_to_num(data2_iceCube / background2_iceCube) - 1)

# %% [markdown]
# #### Combined Graph - 3

# %%
#Combining the (3rd + 4th) bin of IceCube with bin3 of HAWC
data3_iceCube = hp.read_map(IceCube_usage_file_path[2], field = 0)
background3_iceCube = hp.read_map(IceCube_usage_file_path[2], field = 1)
data3_iceCube = data3_iceCube + data2_iceCube
background3_iceCube = background3_iceCube + background2_iceCube
rel_int3_iceCube = (np.nan_to_num(data3_iceCube / background3_iceCube) - 1)
plot_id_w_errors_icecube(data3_iceCube, background3_iceCube, rel_int3_iceCube, top = -17, bottom = -29)

data3_hawc = hp.read_map('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/bin3/data_HAWC_64_360.fits')
rel_int3_hawc = hp.read_map('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/bin3/CR_HAWC_64_360_iteration20.fits')
background3_hawc = data3_hawc / (rel_int3_hawc + 1)
plot_1d_w_errrors(data3_hawc , background3_hawc , rel_int3_hawc , top = -17, bottom = -29)
plt.gca().invert_xaxis()
plt.legend(loc = 'lower left')
plt.show()
# Out:
# /tmp/ipykernel_329/3681831628.py:6: RuntimeWarning: invalid value encountered in divide
#   rel_int3_iceCube = (np.nan_to_num(data3_iceCube / background3_iceCube) - 1)

# %%
data3_iceCube = hp.read_map(IceCube_usage_file_path[2], field = 0)
background3_iceCube = hp.read_map(IceCube_usage_file_path[2], field = 1)
data3_iceCube = data3_iceCube + data2_iceCube
background3_iceCube = background3_iceCube + background2_iceCube
rel_int3_iceCube = (np.nan_to_num(data3_iceCube / background3_iceCube) - 1)

data3_hawc = hp.read_map('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/bin3/data_HAWC_64_360.fits')
rel_int3_hawc = hp.read_map('/data/user/juancarlos/anisotropy/HAWC/local/pass5/reco/bin3/CR_HAWC_64_360_iteration20.fits')
background3_hawc = data3_hawc / (rel_int3_hawc + 1)

#chi_squared test for Combined Graph - 3
yerr_hawc_3 , bin_vals_hawc_3 = calculate_y_errors_hawc(data3_hawc, background3_hawc, rel_int3_hawc, top = -17, bottom = -29, alpha = 1)
yerr_icecube_3 , bin_vals_icecube_3 = calculate_y_errors_icecube(data3_iceCube, background3_iceCube,rel_int3_iceCube, top = -17, bottom = -29, alpha = 20)
chi_squared_test_result_3 = chi_squared(bin_vals_icecube_3 , bin_vals_hawc_3 , yerr_icecube_3 , yerr_hawc_3 )
print(chi_squared_test_result_3)
# Out:
# 66548.32324906712
# /tmp/ipykernel_329/1711476686.py:5: RuntimeWarning: invalid value encountered in divide
#   rel_int3_iceCube = (np.nan_to_num(data3_iceCube / background3_iceCube) - 1)

# %% [markdown]
# #### Combining all the plots into one plot

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5), sharex=True, sharey=True, gridspec_kw={'hspace': 0, 'wspace': 0.076})

# Plot for the 1st bin
plt.sca(axs[0])
plot_1d_w_errors(data1_iceCube, background1_iceCube, rel_int1_iceCube, 
                 top = -21, bottom = -24, alpha = 20, show_plot = True, observatory = True)
plot_1d_w_errors(data1_hawc, background1_hawc, rel_int1_hawc, 
                 top = -21, bottom = -24, alpha = 1, show_plot = True, observatory = False)
axs[0].set_xlabel("")
axs[0].set_ylabel("Relative Intensity[10^-3]")
axs[0].set_title("10 Tev")
axs[0].legend(loc = 'lower left')
plt.gca().invert_xaxis()

# Plot for the 2nd bin
plt.sca(axs[1])
plot_1d_w_errors(data2_iceCube, background2_iceCube, rel_int2_iceCube, 
                 top = -18, bottom = -29, alpha = 20, show_plot = True, observatory = True)
plot_1d_w_errors(data2_hawc, background2_hawc, rel_int2_hawc, 
                 top = -18, bottom = -29, alpha = 1, show_plot = True, observatory = False)
axs[1].set_xlabel("RA (°)")  # Empty string for x-label
axs[1].set_ylabel("")
axs[1].set_title("38 Tev")
plt.gca().invert_xaxis()

# Plot for the (3rd + 4th) bin
plt.sca(axs[2])
plot_id_w_errors_icecube(data3_iceCube, background3_iceCube, rel_int3_iceCube, top=-17, bottom=-29, alpha=20)
plot_1d_w_errrors(data3_hawc, background3_hawc, rel_int3_hawc, top=-17, bottom=-29, alpha=1)
axs[2].set_xlabel("")  # Empty string for x-label
axs[2].set_ylabel("")
axs[2].set_title("100 TeV")
plt.gca().invert_xaxis()

fig.suptitle("1-D projection of adjacent declination bins", fontweight = 'heavy')

# Show the plot
plt.show()
